# %%
import pandas as pd

data = 'WebVisualization/Assets:Images/cities.csv'

cities_csv = pd.read_csv(data, encoding='utf-8')

cities_csv
# Out:
#                 City Country                 Date  Latitude  Longitude  \
# 0             Edzell      GB  2020-06-16 01:00:23     56.81      -2.65
# 1    Arraial do Cabo      BR  2020-06-16 01:00:24    -22.97     -42.03
# 2          Iskateley      RU  2020-06-16 01:00:24     67.68      53.15
# 3            Mataura      NZ  2020-06-16 01:00:24    -46.19     168.86
# 4              Bilma      NE  2020-06-16 01:00:24     18.69      12.92
# ..               ...     ...                  ...       ...        ...
# 549    Marsh Harbour      BS  2020-06-16 01:01:23     26.54     -77.06
# 550        Manokwari      ID  2020-06-16 01:01:24     -0.87     134.08
# 551  Haines Junction      CA  2020-06-16 01:01:24     60.75    -137.51
# 552           Guaíba      BR  2020-06-16 01:00:25    -30.11     -51.33
# 553  Havre-St-Pierre      CA  2020-06-16 01:01:24     50.23     -63.60
#
#      Cloudiness  Humidity  Max Temperature  Wind Speed
# 0            90       100            55.00        2.24
# ...

# %%
cities_csv = cities_csv.to_html()

print(cities_csv)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Cloudiness</th>
#       <th>Humidity</th>
#       <th>Max Temperature</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Edzell</td>
#       <td>GB</td>
#       <td>2020-06-16 01:00:23</td>
#       <td>56.81</td>
#       <td>-2.65</td>
#       <td>90</td>
#       <td>100</td>
#       <td>55.00</td>
#       <td>2.24</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Arraial do Cabo</td>
#       <td>BR</td>
#       <td>2020-06-16 01:00:24</td>
#       <td>-22.97</td>
#       <td>-42.03</td>
#       <td>98</td>
#       <td>79</td>
#       <td>69.51</td>
#       <td>13.71</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Iskateley</td>
#       <td>RU</td>
# ...
